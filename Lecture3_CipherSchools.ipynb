# %%
# Addition

a=10
b=15
print(a+b)
# Out:
# 25

# %%
# Allowed syntax for initialising variables

a=10;b=10
print(a+b)

a,b =10,20
print(a+b)
# Out:
# 20
# 30

# %%
#Not Allowed

a=5 , b=10
print(a+b)
# Out:
#   File "<ipython-input-9-25f5231344d4>", line 3
#     a=5 , b=10
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# Python is case Sensitive

a=10
b=20
A=30
print(a+b,A+b)
# Out:
# 30 50
